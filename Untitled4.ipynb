# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielSchmidt1/DanielSchmidt1/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 27.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python yolo_detect.py --model my_model.pt --source /content/drive/MyDrive/output.mp4 --no-display
# Out:
# Starting video at 0.0 seconds.
# Using source video FPS for logs: 29.97
# Video duration: 00:40:17.548 (72454 frames)
# Saving output video to: /content/output_videos/1_frog_locations_output.mp4
# Saving frog logs to: /content/output_logs/1_frog_locations_output.txt
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 2 packages in 467ms
# Prepared 1 package in 191ms
# Installed 1 package in 9ms
#  + lap==0.5.13
#
# requirements: AutoUpdate success ✅ 1.1s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# Progress  12.70% | Video 00:05:06.973 / 00:40:17.548 | Detections 1 | ETA 01:28:55.753Logged frog touch: Frog-ID 1 at 00:05:07.006
# Progress  41.67% | Video 00:16:47.373 / 00:40:17.548 | Detections 1 | ETA 01:03:43.467Logged frog touch: Frog-ID 2 at 00:16:47.506
# ...
